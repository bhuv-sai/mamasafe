# %%
import pickle
import numpy as np

# %%
model = pickle.load(open("pregnancy_model.pkl", "rb"))

sample = np.array([[32,2,3,1,1,0,0]])

prediction = model.predict(sample)

print("Predicted Risk:", prediction[0])
# Out:
# Predicted Risk: Monitor
# /home/rgukt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
sample=np.array([[35, 1, 0, 0, 1, 0, 0]])

# %%
model.predict(sample)[0]
# Out:
# /home/rgukt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'Normal'
